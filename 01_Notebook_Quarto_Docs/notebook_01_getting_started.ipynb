# %% [markdown]
# # 🐍 Notebook 1: Getting Started with Python
# **Basado en Python Crash Course, 3ra Edición — Capítulo 1**
#
# ---
#
# ## 🎯 Objetivos de aprendizaje
# - Entender qué es Python y por qué usarlo
# - Ejecutar tu primer programa en Python
# - Conocer el intérprete interactivo
# - Configurar tu entorno de trabajo
#
# > 💡 **Para quien ya programa:** Python se distingue por su sintaxis limpia y legible. Si vienes de otros lenguajes deprogramación como R Java o C++, notarás inmediatamente que no hay llaves `{}` ni puntos y coma obligatorios.
#
# ---

# %% [markdown]
# ## 1.1 ¿Por qué Python?
#
# Python es un lenguaje de propósito general que destaca por:
#
# | Característica | Descripción |
# |---|---|
# | **Legibilidad** | El código se parece al inglés natural |
# | **Versatilidad** | Web, data science, IA, automatización |
# | **Ecosistema** | Miles de librerías disponibles |
# | **Comunidad** | Una de las más grandes del mundo |
#
# **Comparación rápida:**
# ```R
# // R
# print("Hola Mundo");
#
# // Python equivalente:
# print("Hola Mundo")
# ```

# %%
# Tu primer programa en Python
# La función print() muestra texto en pantalla
print("¡Hola, Python!")
print("Bienvenido al mundo de la programación con Python")
# Out:
# ¡Hola, Python!
# Bienvenido al mundo de la programación con Python

# %% [markdown]
# ## 1.2 El Intérprete Interactivo
#
# Python puede ejecutarse de dos formas:
# 1. **Interactivo** (línea a línea) — ideal para probar cosas
# 2. **Scripts** (archivos .py) — para programas completos
#
# En Jupyter ya estás usando un entorno interactivo.

# %%
# Python como calculadora — prueba el intérprete
2 + 3
# Out:
# 5

# %%
# Operaciones básicas
print(10 * 5)
print(2 ** 10)   # 2 elevado a la 10
print(17 / 3)    # División normal
print(17 // 3)   # División entera
print(17 % 3)    # Módulo (resto)
# Out:
# 50
# 1024
# 5.666666666666667
# 5
# 2

# %% [markdown]
# ## 1.3 Comentarios en Python
#
# Los comentarios son notas para los humanos — Python los ignora.

# %%
# Esto es un comentario de una línea
print("Los comentarios no se ejecutan")  # Comentario al final de línea

# En Python NO existe /* comentario multilínea */ como en C/Java
# Se usan múltiples # o strings con triple comilla (como docstrings)
"""
Este es un string multilínea que a veces se usa como comentario.
No es un comentario oficial, pero funciona en la práctica.
"""
print("Después del bloque de texto")
# Out:
# Los comentarios no se ejecutan
# Después del bloque de texto

# %% [markdown]
# ---
# ## ✏️ Ejercicios Prácticos
#
# ### Ejercicio 1.1: Mensaje Personalizado
# Imprime un mensaje de bienvenida que incluya tu nombre y el lenguaje en el que ya programas.

# %%
# Ejercicio 1.1 — Tu turno
# Modifica el código para incluir tu nombre
print("Hola, me llamo [TU NOMBRE]")
print("Vengo del lenguaje [TU LENGUAJE]")
print("Y estoy aprendiendo Python")
# Out:
# Hola, me llamo [TU NOMBRE]
# Vengo del lenguaje [TU LENGUAJE]
# Y estoy aprendiendo Python

# %% [markdown]
# ### Ejercicio 1.2: Calculadora Simple
# Calcula y muestra los resultados de estas operaciones matemáticas.

# %%
# Ejercicio 1.2
# Calcula: el área de un círculo con radio 5
# Fórmula: π * r²  (usa 3.14159 para π)

radio = 5
pi = 3.14159

# Escribe aquí tu código:
area = pi * radio ** 2
print(f"El área del círculo es: {area}")
# Out:
# El área del círculo es: 78.53975

# %% [markdown]
# ---
# ## ✅ Soluciones

# %%
# Solución 1.1
print("Hola, me llamo Ana García")
print("Vengo de Java y JavaScript")
print("Y estoy aprendiendo Python — ¡es mucho más conciso!")
# Out:
# Hola, me llamo Ana García
# Vengo de Java y JavaScript
# Y estoy aprendiendo Python — ¡es mucho más conciso!

# %%
# Solución 1.2
radio = 5
pi = 3.14159
area = pi * radio ** 2
print(f"Área del círculo con radio {radio}: {area:.2f}")
# El :.2f formatea con 2 decimales
# Out:
# Área del círculo con radio 5: 78.54

# %% [markdown]
# ---
# ## 🚀 Mini Proyecto: Tarjeta de Presentación
#
# Crea una "tarjeta de presentación" usando print(). Debe incluir nombre, lenguaje favorito anterior, y un dato curioso sobre ti.

# %%
# MINI PROYECTO — Tarjeta de Presentación
print("=" * 40)
print("       TARJETA DE PRESENTACIÓN")
print("=" * 40)
print("Nombre:          [TU NOMBRE]")
print("Lenguaje previo: [TU LENGUAJE]")
print("Dato curioso:    [ALGO INTERESANTE]")
print("Meta en Python:  [QUÉ QUIERES HACER]")
print("=" * 40)
# Out:
# ...
#        TARJETA DE PRESENTACIÓN
# ...
# Nombre:          [TU NOMBRE]
# Lenguaje previo: [TU LENGUAJE]
# Dato curioso:    [ALGO INTERESANTE]
# Meta en Python:  [QUÉ QUIERES HACER]
# ...

# %% [markdown]
# ---
# ## 🏆 Desafío (sin solución)
#
# **Desafío 1:** Calcula cuántos segundos hay en un año. Muestra el resultado con un mensaje descriptivo.
#
# **Desafío 2:** Python puede manejar números enormes sin problema. Calcula 2^1000 y observa el resultado.
#
# ---
# ## 📝 Autoevaluación
#
# Responde en la celda de markdown (doble clic para editar):
#
# 1. ¿Cuál es la función para mostrar texto en Python? →
# 2. ¿Cómo se escribe un comentario de una línea? →
# 3. ¿Qué operador se usa para potencias en Python? →
# 4. ¿Diferencia entre `/` y `//`? →
